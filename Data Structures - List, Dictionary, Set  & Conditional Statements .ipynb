# %% [markdown]
# # List

# %% [markdown]
# ## 1.List Creation

# %%
Age_list=[24,25,26,27,28]

# %%
Name_list= ["sarath","indrajith","anit","anisha","sreeja"]

# %% [markdown]
# ## 2.List Operation

# %%
Name_list.append("Yazhini")
print(Name_list)
# Out:
# ['sarath', 'indrajith', 'anit', 'anisha', 'sreeja', 'Yazhini']

# %%
Age_list.insert(2,30)
print(Age_list)
# Out:
# [24, 25, 30, 26, 27, 28]

# %%
Name_list.remove("Yazhini")

# %%
Name_list
# Out:
# ['sarath', 'indrajith', 'anit', 'anisha', 'sreeja']

# %%
Age_list.pop()
# Out:
# 28

# %%
Age_list.extend([29,30,26])
print(Age_list)
# Out:
# [24, 25, 30, 26, 27, 29, 30, 26]

# %%
Age_list.sort(reverse=True)
print(Age_list)
# Out:
# [30, 30, 29, 27, 26, 26, 25, 24]

# %%
max(Age_list)
min(Age_list)
sum(Age_list)
print (max(Age_list))
print (min(Age_list))
print (sum(Age_list))
# Out:
# 30
# 24
# 217

# %% [markdown]
# ## Accessing List Elements

# %%
print (Name_list[0])
# Out:
# sarath

# %%
print(Name_list[-1])
# Out:
# sreeja

# %%
Name_list[2:5]
# Out:
# ['anit', 'anisha', 'sreeja']

# %%
Name_list[::-1]
# Out:
# ['sreeja', 'anisha', 'anit', 'indrajith', 'sarath']

# %% [markdown]
# # Dictionary
# ## Creation,Modification and Access

# %%
Student_marks={
    "Indrajith":75,
    "Anisha":85,
    "Sarath": 70,
    "Anit":80,
    "Sreeja":73
}

# %%
print(Student_marks["Anisha"])
# Out:
# 85

# %%
Student_marks["Janani"]=80

# %%
Student_marks["Anit"]=82

# %%
print(Student_marks["Anit"])
# Out:
# 82

# %%
print(Student_marks.keys())
# Out:
# dict_keys(['Indrajith', 'Anisha', 'Sarath', 'Anit', 'Sreeja', 'Janani'])

# %%
print(Student_marks.values())
# Out:
# dict_values([75, 85, 70, 82, 73, 80])

# %%
print(Student_marks.items())
# Out:
# dict_items([('Indrajith', 75), ('Anisha', 85), ('Sarath', 70), ('Anit', 82), ('Sreeja', 73), ('Janani', 80)])

# %% [markdown]
# # Set
# ## Operations

# %%
my_set={'a','e','i','o','u','a','a','i'}

# %%
print(my_set)
# Out:
# {'e', 'a', 'u', 'i', 'o'}

# %% [markdown]
# #### set automatically deletes the dupilates and displays unique set numbers

# %%
my_set[4]="s"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 my_set[4]="s"
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# ### it is not an indexed sequence, and is not valid indexing

# %%
set1= {1, 3, 5, 7, 9}

# %%
set2={2, 3, 5, 8, 10}

# %%
set1.union(set2)

# %%
set1.intersection(set2)

# %% [markdown]
# # Operators & Conditional Statements
# ### IF, ELIF, ELSE

# %%
score=int(input("Enter your score(0 to 10):"))
if score >7:
    print("Above Average: Excellent Work")
elif score>=4:
    print("Average: Good effort! Keep practicing, there's room for improvement.")
else:
    print("Below Average: Need to Improve your performance, consistent practice will lead to better results")
# Out:
# Enter your score(0 to 10): 7
# Average: Good effort! Keep practicing, there's room for improvement.
